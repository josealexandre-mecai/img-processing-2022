# %%
from predictors import *

# %%
# %matplotlib inline

# %%
# Type the image path in your local machine 
#i.e.: ./waste_images/showcase\\showcase1.JPG
image_path = str(input()).rstrip()
# Out:
# ./waste_images/showcase\\showcase1.JPG

# %%
# Source: https://www.alamy.com/
display(Image(filename=image_path, width=300))

# %%
# Type the number of the option to select the models (4 options):

# 1 (Models trained with imbalanced dataset and images with background) 
# 2 (Models trained with imbalanced dataset and images without background) 
# 3 (Models trained with balanced dataset and images with background)
# 4 (Models trained with balanced dataset and images without background)

#i.e.: 1

option = str(input()).rstrip()
# Out:
# 1

# %%
main(image_path, option)
# Out:
# Prediction BRISK :
#  ['Printed Circuit Board']
#
# Probabilities BRISK:
#  {'Aluminium': 0.0, 'Battery': 0.0, 'Cable and Wire': 0.0, 'Cardboard and Paper': 0.0, 'Connector': 0.0, 'Copper': 0.0, 'Iron': 0.0, 'Magnetic Tape': 0.0, 'Printed Circuit Board': 1.0, 'Printer Ribbon and Toner': 0.0, 'Tube and Screen': 0.0, 'Water Pump': 0.0}
#
# Prediction GLCM :
#  ['Tube and Screen']
#
# Probabilities GLCM:
#  {'Aluminium': 0.0683, 'Battery': 0.1086, 'Cable and Wire': 0.0812, 'Cardboard and Paper': 0.0827, 'Connector': 0.095, 'Copper': 0.0531, 'Iron': 0.0521, 'Magnetic Tape': 0.06, 'Printed Circuit Board': 0.0759, 'Printer Ribbon and Toner': 0.0902, 'Tube and Screen': 0.2172, 'Water Pump': 0.0158}
#
# Prediction LBP :
#  ['Printed Circuit Board']
#
# Probabilities LBP:
#  {'Aluminium': 0.0792, 'Battery': 0.045, 'Cable and Wire': 0.08, 'Cardboard and Paper': 0.0307, 'Connector': 0.0813, 'Copper': 0.0348, 'Iron': 0.0137, 'Magnetic Tape': 0.0214, 'Printed Circuit Board': 0.2868, 'Printer Ribbon and Toner': 0.0256, 'Tube and Screen': 0.2488, 'Water Pump': 0.0526}

# %% [markdown]
# Obs: As the documentation (https://scikit-learn.org/dev/modules/svm.html#scores-and-probabilities) states, there is no guarantee that predict_proba and predict will give consistent results on SVC.
