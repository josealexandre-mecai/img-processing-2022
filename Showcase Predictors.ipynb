# %%
from predictors import *

# %%
# %matplotlib inline

# %%
# Type the image path in your local machine (it needs to be a .JPG image)
#i.e.: ./waste_images/showcase\\showcase1.JPG 
image_path = str(input()).rstrip()

# %%
# Source: https://www.alamy.com/
display(Image(filename=image_path, width=300))

# %%
# Type the number of the option to select the models (4 options):

# 1 (Models trained with imbalanced dataset and images with background) 
# 2 (Models trained with imbalanced dataset and images without background) 
# 3 (Models trained with balanced dataset and images with background)
# 4 (Models trained with balanced dataset and images without background)

#i.e.: 1

option = str(input()).rstrip()

# %%
predict(image_path, option)
# Out:
# d:\ProgramFiles\lib\site-packages\sklearn\base.py:329: UserWarning: Trying to unpickle estimator DecisionTreeClassifier from version 0.24.1 when using version 0.23.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# d:\ProgramFiles\lib\site-packages\sklearn\base.py:329: UserWarning: Trying to unpickle estimator RandomForestClassifier from version 0.24.1 when using version 0.23.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# d:\ProgramFiles\lib\site-packages\sklearn\base.py:329: UserWarning: Trying to unpickle estimator StandardScaler from version 0.24.1 when using version 0.23.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# ...

# %% [markdown]
# Obs: As the documentation (https://scikit-learn.org/dev/modules/svm.html#scores-and-probabilities) states, there is no guarantee that predict_proba and predict will give consistent results on SVC.
