# %%
from predictors import *

# %%
# %matplotlib inline

# %% [markdown]
# # Classification

# %%
# Type the image path in your local machine (it needs to be a .JPG image)
#i.e.: ./waste_images/showcase/query\\showcase2.JPG 
image_path = str(input()).rstrip()
# Out:
# ./waste_images/showcase/query\\showcase2.JPG

# %%
# Source: https://www.alamy.com/
display(Image(filename=image_path, width=300))

# %%
# Type the number of the option to select the models (4 options):

# 1 (Models trained with imbalanced dataset and images with background) 
# 2 (Models trained with imbalanced dataset and images without background) 
# 3 (Models trained with balanced dataset and images with background)
# 4 (Models trained with balanced dataset and images without background)

#i.e.: 1

option = str(input()).rstrip()
# Out:
# 4

# %%
predict(image_path, option)
# Out:
# Prediction BRISK:  ['Tube and Screen']
#
# Probabilities BRISK:
#  {'Aluminium': 0.0486, 'Battery': 0.0833, 'Cable and Wire': 0.0264, 'Cardboard and Paper': 0.0465, 'Connector': 0.0165, 'Copper': 0.0486, 'Iron': 0.0707, 'Magnetic Tape': 0.0783, 'Printed Circuit Board': 0.1034, 'Printer Ribbon and Toner': 0.1393, 'Tube and Screen': 0.1763, 'Water Pump': 0.1622}
#
# Prediction GLCM:  ['Printed Circuit Board']
#
# Probabilities GLCM:
#  {'Aluminium': 0.0, 'Battery': 0.1666, 'Cable and Wire': 0.0, 'Cardboard and Paper': 0.0, 'Connector': 0.1035, 'Copper': 0.0, 'Iron': 0.0, 'Magnetic Tape': 0.0, 'Printed Circuit Board': 0.2549, 'Printer Ribbon and Toner': 0.1943, 'Tube and Screen': 0.2407, 'Water Pump': 0.04}
#
# Prediction LBP:  ['Battery']
#
# Probabilities LBP:
#  {'Aluminium': 0.0031, 'Battery': 0.4073, 'Cable and Wire': 0.2143, 'Cardboard and Paper': 0.0032, 'Connector': 0.0033, 'Copper': 0.0443, 'Iron': 0.2438, 'Magnetic Tape': 0.0061, 'Printed Circuit Board': 0.007, 'Printer Ribbon and Toner': 0.0661, 'Tube and Screen': 0.0008, 'Water Pump': 0.0007}

# %% [markdown]
# Obs: As the documentation (https://scikit-learn.org/dev/modules/svm.html#scores-and-probabilities) states, there is no guarantee that predict_proba and predict will give consistent results on SVC.

# %% [markdown]
# # Image Retrieval

# %%
from image_retrieval import *

# %%
# %matplotlib inline

# %%
# Type the dataset path in your local machine (it needs to be a .JPG image)
#i.e.: './waste_images/showcase/dataset/' 
dataset_path = str(input()).rstrip()
# Out:
# ./waste_images/showcase/dataset/

# %%
# Type the image path in your local machine (it needs to be a .JPG image)
#i.e.: ./waste_images/showcase/query\\showcase2.JPG 
image_path = str(input()).rstrip()
# Out:
# ./waste_images/showcase/query\\showcase2.JPG

# %%
# Source: https://www.alamy.com/
display(Image(filename=image_path, width=300))

# %%
# Type the number of the option to select the models (4 options):

# 1 (Models trained with imbalanced dataset and images with background) 
# 2 (Models trained with imbalanced dataset and images without background) 
# 3 (Models trained with balanced dataset and images with background)
# 4 (Models trained with balanced dataset and images without background)

#i.e.: 1

option = str(input()).rstrip()
# Out:
# 1

# %%
retrieve_images(dataset_path, image_path, option, "glcm")  # imbalanced dataset and images with background - GLCM

# %%
retrieve_images(dataset_path, image_path, option, 'lbp') # imbalanced dataset and images with background - LBP

# %%
retrieve_images(dataset_path, image_path, '2', "glcm") # imbalanced dataset and images without background - GLCM

# %%
retrieve_images(dataset_path, image_path, '2', "lbp") # imbalanced dataset and images without background - LBP

# %%
retrieve_images(dataset_path, image_path, '3', "glcm") # balanced dataset and images with background - GLCM

# %%
retrieve_images(dataset_path, image_path, '3', "lbp") # balanced dataset and images with background - LBP

# %%
retrieve_images(dataset_path, image_path, '4', "glcm") # balanced dataset and images without background - GLCM

# %%
retrieve_images(dataset_path, image_path, '4', "lbp") # balanced dataset and images without background - LBP
